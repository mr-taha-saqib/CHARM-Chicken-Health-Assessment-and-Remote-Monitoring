# %%
# Install YOLOv8 and its dependencies
# !pip install ultralytics --upgrade

# Install OpenCV
# !pip install opencv-python-headless
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.135)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cpu)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python-headless) (2.0.2)

# %%
import os
import cv2
from pathlib import Path
from ultralytics import YOLO
from ultralytics.trackers import register_tracker
import numpy as np
from concurrent.futures import ThreadPoolExecutor
import threading
import torch
import torchvision.transforms as transforms
from PIL import Image
import torchvision.models as models

# Step 1: Define architectures
resnet_model = models.resnet50(pretrained=False)
resnet_model_neck = models.resnet50(pretrained=False)

num_features = resnet_model.fc.in_features
resnet_model.fc = torch.nn.Linear(num_features, 3)        # 3 classes
resnet_model_neck.fc = torch.nn.Linear(num_features, 3)   # 3 classes for neck

# Step 2: Load weights
resnet_model.load_state_dict(torch.load("/content/drive/MyDrive/FYP models/models/resnet50(3_fullchicken)/resnet50_3class_best_full.pth", map_location="cuda" if torch.cuda.is_available() else "cpu"))
resnet_model_neck.load_state_dict(torch.load("/content/drive/MyDrive/FYP models/models/resnet50(3_neck)/resnet50_3class_best_neck.pth", map_location="cuda" if torch.cuda.is_available() else "cpu"))

# Step 3: Set device and eval
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
resnet_model = resnet_model.to(device)
resnet_model_neck = resnet_model_neck.to(device)

resnet_model.eval()
resnet_model_neck.eval()

# Transform (must match your training)
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),  # or whatever your input size is
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Class labels full body
CLASS_LABELS = {
    0: "Marek",
    1: "Disease",
    2: "Healthy"
}
# Class labels neck area
CLASS_LABELS1 = {
    0: "infectious_coryza",
    1: "fowl_pox",
    2: "Healthy"
}
# Constants
DETECTION_MODEL_PATH1 = "/content/drive/MyDrive/FYP models/models/yolo_detection/best .pt"
DETECTION_MODEL_PATH2 = "/content/drive/MyDrive/FYP models/models/neck_detection/best.pt"
# Load YOLO models
model = YOLO(DETECTION_MODEL_PATH1)
model_neck = YOLO(DETECTION_MODEL_PATH2)
QUALITY_THRESHOLDS1 = {
    "blur": 23.0,             # Adjust based on how sharp your objects are
}
QUALITY_THRESHOLDS_Neck = {
    "blur": 19.0,             # Adjust based on how sharp your objects are
}
#object_predictions = {}  # {track_id: {"quality": quality, "prediction": "Healthy"}}
max_threads = 22
thread_lock = threading.Lock()
executor = ThreadPoolExecutor(max_workers=max_threads)

# %%
def calculate_quality(frame, bbox,label1="body"):
    x1, y1, x2, y2 = bbox
    crop = frame[y1:y2, x1:x2]
    if label1=="body":
        QUALITY_THRESHOLDS = QUALITY_THRESHOLDS1
    else:
        QUALITY_THRESHOLDS = QUALITY_THRESHOLDS_Neck
    if crop.size == 0:
        return 0.0, False  # avoid crash

    # Convert to grayscale for blur & brightness
    gray = cv2.cvtColor(crop, cv2.COLOR_BGR2GRAY)

    blur = cv2.Laplacian(gray, cv2.CV_64F).var()
    brightness = np.mean(gray)



    # Check thresholds
    quality_ok = (
        blur > QUALITY_THRESHOLDS["blur"]
    )

    # Combine into one score if needed (optional)
    combined_score = (blur + brightness) / 2

    return combined_score, quality_ok

# %%
def ensure_output_dir(input_path):
    input_path = Path(input_path)
    if input_path.is_file():
        out_dir = input_path.parent / f"{input_path.stem}_output_yolo"
    else:
        out_dir = input_path / "output_yolo"
    os.makedirs(out_dir, exist_ok=True)
    return out_dir

# %%
def process_single_image(img_path, output_dir):
    frame = cv2.imread(str(img_path))
    results = model.predict(frame, conf=0.5, iou=0.7)[0]  # Only detection, no tracking

    temp_id = 0

    if results.boxes is not None and len(results.boxes) > 0:
        for box in results.boxes.xyxy:
            x1, y1, x2, y2 = map(int, box)
            track_id = temp_id
            temp_id += 1

            try:
                quality, quality_ok = calculate_quality(frame, (x1, y1, x2, y2))
                crop = frame[y1:y2, x1:x2]

                if quality_ok:
                    pred_label = predict_with_resnet(crop)

                    # Assign color based on prediction
                    if pred_label == "Healthy":
                        box_color = (0, 255, 0)
                    elif pred_label == "Marek":
                        box_color = (0, 165, 255)
                    elif pred_label == "Disease":
                        box_color = (0, 0, 255)

                    # 🧠 Neck classification without checking containment
                    neck_results = model_neck.predict(frame, conf=0.5, iou=0.5)[0]
                    if neck_results.boxes is not None and len(neck_results.boxes) > 0:
                        for neck_box in neck_results.boxes.xyxy:
                            nx1, ny1, nx2, ny2 = map(int, neck_box)
                            try:
                                neck_crop = frame[ny1:ny2, nx1:nx2]
                                neck_quality, neck_quality_ok = calculate_quality(frame, (nx1, ny1, nx2, ny2),"neck")
                                if neck_quality_ok:
                                    neck_pred = predict_with_resnet_neck(neck_crop)

                                    if neck_pred != "Healthy":
                                        neck_color = (0, 165, 255) if neck_pred == "infectious_coryza" else (0, 0, 255)
                                        cv2.rectangle(frame, (nx1, ny1), (nx2, ny2), neck_color, 2)
                                        cv2.putText(frame, f"Neck: {neck_pred}", (nx1, ny2 + 20),
                                                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, neck_color, 2)
                            except Exception as e:
                                print(f"❌ Neck classification error: {e}")
                else:
                    pred_label = "LowQuality"
                    box_color = (255, 255, 255)

                # 🟩 Draw full-body bounding box
                cv2.rectangle(frame, (x1, y1), (x2, y2), box_color, 2)

                # 🏷️ Label
                label = f"{pred_label} (ID:{track_id})"
                label_y = y1 - 10 if y1 - 10 > 10 else y1 + 20
                cv2.putText(frame, label, (x1, label_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, box_color, 2)

                # 📏 Quality score
                q_color = (0, 255, 255) if quality_ok else (0, 0, 255)
                cv2.putText(frame, f"Q:{quality:.2f}", (x1, y2 + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, q_color, 2)

            except Exception as e:
                print(f"❌ Error in {Path(img_path).name}: {e}")

    else:
        print(f"🚫 No objects detected in image: {Path(img_path).name}")

    out_path = os.path.join(output_dir, f"{Path(img_path).stem}_classified.jpg")
    cv2.imwrite(out_path, frame)
    print(f"🖼️ Saved: {out_path}")

# %%
def process_image_directory(input_dir, output_dir):
    image_files = [f for f in Path(input_dir).glob("*") if f.suffix.lower() in [".jpg", ".png", ".jpeg"]]
    for img_path in image_files:
        process_single_image(img_path, output_dir)

# %%
def quality_and_classify(track_id, frame, box):
    x1, y1, x2, y2 = box
    crop = frame[y1:y2, x1:x2]

    try:
        # ✅ Validate crop size to prevent model errors
        if crop.size == 0 or crop.shape[0] < 10 or crop.shape[1] < 10:
            print(f"[Crop Error] ID {track_id}: Invalid crop")
            return

        # ✅ Assess quality
        quality, quality_ok = calculate_quality(frame, box)

        # ✅ Proceed only if quality is sufficient and better than previous
        if quality_ok:
            with thread_lock:
                last = object_predictions.get(track_id)
                if last is None or quality > last["quality"]:
                    print(f"[Classify Start] ID {track_id}")
                    prediction = predict_with_resnet(crop)
                    print(f"[Classify Done] ID {track_id}")
                    object_predictions[track_id] = {
                        "quality": quality,
                        "prediction": prediction
                    }

    except Exception as e:
        print(f"[Thread error] ID {track_id}: {e}")

# %%
def classify_neck_area(frame, full_body_box):
    try:
        neck_results = model_neck.predict(frame, conf=0.5, iou=0.5)[0]

        if neck_results.boxes is not None and len(neck_results.boxes) > 0:
            for neck_box in neck_results.boxes.xyxy:
                nx1, ny1, nx2, ny2 = map(int, neck_box)

                # ✅ Only consider neck boxes inside full-body box
                fx1, fy1, fx2, fy2 = full_body_box
                if not (fx1 <= nx1 <= fx2 and fx1 <= nx2 <= fx2 and
                        fy1 <= ny1 <= fy2 and fy1 <= ny2 <= fy2):
                    continue  # skip neck boxes outside tracked chicken

                neck_crop = frame[ny1:ny2, nx1:nx2]

                try:
                    neck_quality, neck_quality_ok = calculate_quality(frame, (nx1, ny1, nx2, ny2), "neck")
                    if neck_quality_ok:
                        neck_pred = predict_with_resnet_neck(neck_crop)

                        # ✅ Only draw if not healthy
                        if neck_pred != "Healthy":
                            neck_color = (0, 165, 255) if neck_pred == "infectious_coryza" else (0, 0, 255)
                            cv2.rectangle(frame, (nx1, ny1), (nx2, ny2), neck_color, 2)
                            cv2.putText(frame, f"Neck: {neck_pred}", (nx1, ny2 + 20),
                                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, neck_color, 2)

                except Exception as e:
                    print(f"[Neck Detection Error] {e}")
    except Exception as e:
        print(f"[Neck Detection Outer Error] {e}")

# %%
def process_video(video_path, output_dir):
    cap = cv2.VideoCapture(str(video_path))
    out_video_path = os.path.join(output_dir, f"{Path(video_path).stem}_tracked.mp4")

    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    writer = cv2.VideoWriter(out_video_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

    frame_buffer = []  # [(frame, [(box, track_id)])]

    print("🔄 Starting Phase 1: Detection, Tracking, Classification")

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        results = model.track(frame, persist=True, conf=0.5, iou=0.5, tracker="botsort.yaml")[0]
        detections = []

        if results.boxes.id is not None and len(results.boxes.id) > 0:
            for box, track_id in zip(results.boxes.xyxy, results.boxes.id):
                x1, y1, x2, y2 = map(int, box)
                track_id = int(track_id)

                # Launch classification threads
                executor.submit(quality_and_classify, track_id, frame.copy(), (x1, y1, x2, y2))
                executor.submit(classify_neck_area, frame.copy(), (x1, y1, x2, y2))

                detections.append(((x1, y1, x2, y2), track_id))
        frame_buffer.append((frame.copy(), detections))

    cap.release()

    print("⏳ Waiting for all threads to finish...")
    executor.shutdown(wait=True)
    print("✅ All classifications completed")

    print("🖊️ Starting Phase 2: Annotating and Writing Video")

    for frame, detections in frame_buffer:
        for (x1, y1, x2, y2), track_id in detections:
            pred_label = "Unknown"
            pred_color = (128, 128, 128)
            quality = 0.0

            prediction_info = object_predictions.get(track_id)
            if prediction_info:
                pred_label = prediction_info["prediction"]
                quality = prediction_info["quality"]

                if pred_label == "Healthy":
                    pred_color = (0, 255, 0)
                elif pred_label == "Marek":
                    pred_color = (0, 165, 255)
                elif pred_label == "Disease":
                    pred_color = (0, 0, 255)
            else:
                pred_color=(255,255,255)
                pred_label = "LowQuality"

            # Draw final predictions
            cv2.rectangle(frame, (x1, y1), (x2, y2), pred_color, 2)
            cv2.putText(frame, f"ID: {track_id}", (x1, y1 - 25), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
            cv2.putText(frame, pred_label, (x1, y2 + 40), cv2.FONT_HERSHEY_SIMPLEX, 0.6, pred_color, 2)
            cv2.putText(frame, f"Q:{quality:.2f}", (x1, y2 + 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)

        writer.write(frame)

    writer.release()
    print(f"✅ Tracked video saved to: {out_video_path}")

# %%
def predict_with_resnet(crop):
    image = transform(crop).unsqueeze(0).to(device)  # [1, 3, 224, 224]
    with torch.no_grad():
        outputs = resnet_model(image)
        _, predicted = torch.max(outputs, 1)
        label = CLASS_LABELS[predicted.item()]
    return label

# %%
def predict_with_resnet_neck(crop):
    image = transform(crop).unsqueeze(0).to(device)
    with torch.no_grad():
        outputs = resnet_model_neck(image)
        _, predicted = torch.max(outputs, 1)
        label = CLASS_LABELS1[predicted.item()]
    return label

# %%
def run_detection_and_tracking(input_path):
    input_path = Path(input_path)
    output_dir = ensure_output_dir(input_path)

    if input_path.is_file() and input_path.suffix.lower() in [".jpg", ".png", ".jpeg"]:
        process_single_image(input_path, output_dir)

    elif input_path.is_file() and input_path.suffix.lower() in [".mp4", ".avi", ".mov"]:
        # 🔄 Reset object_predictions to avoid contamination between videos
        global object_predictions
        object_predictions = {}  # {track_id: {"quality": quality, "prediction": "Healthy"}}
        if hasattr(model, "predictor") and model.predictor is not None and hasattr(model.predictor, "tracker"):
            model.predictor.tracker = None

        process_video(input_path, output_dir)

    elif input_path.is_dir():
        process_image_directory(input_path, output_dir)

    else:
        print("Unsupported input format.")

# %%
#run_detection_and_tracking("/content/drive/MyDrive/FYP models/test_models/Test_images/chicken-4392787.jpg")
#run_detection_and_tracking("/content/drive/MyDrive/FYP models/test_models/Test_images")
run_detection_and_tracking("/content/drive/MyDrive/FYP models/test_models/test_videos/165148-832090850.mp4")
#/content/drive/MyDrive/FYP models/test_models/test_videos/MXClip_N_C_D.mp4
#/content/drive/MyDrive/FYP models/test_models/test_videos/130614-747879918_large.mp4
#/content/drive/MyDrive/FYP models/test_models/test_videos/165148-832090850.mp4
#/content/drive/MyDrive/FYP models/test_models/test_videos/190142-887464235.mp4
#/content/drive/MyDrive/FYP models/test_models/test_videos/MXClip_CHICKEN FARMING, NEWCASTLE DISEASE Symptoms & Signs in Broiler, Poultry Diseases_2025_03_20_11_59_03_output_yolo
# Out:
# 🔄 Starting Phase 1: Detection, Tracking, Classification
#
# 0: 384x640 1 chicken, 161.0ms
# Speed: 1.4ms preprocess, 161.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [Classify Start] ID 1
#
# [Classify Done] ID 1
# 0: 384x640 1 chicken, 176.7ms
# Speed: 1.6ms preprocess, 176.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# Ultralytics 8.3.135 🚀 Python-3.11.12 torch-2.6.0+cpu CPU (AMD EPYC 9B14)
#
# 0: 384x640 1 chicken, 304.1ms
# Speed: 1.8ms preprocess, 304.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# Ultralytics 8.3.135 🚀 Python-3.11.12 torch-2.6.0+cpu CPU (AMD EPYC 9B14)
#
#
# 0: 384x640 1 chicken, 224.8ms
# Speed: 1.8ms preprocess, 224.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 303.9ms
# Speed: 1.9ms preprocess, 303.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 175.5ms
# Speed: 1.3ms preprocess, 175.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 268.4ms
# Speed: 2.8ms preprocess, 268.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Model summary (fused): 112 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
# 0: 384x640 1 chicken, 255.7ms
# Speed: 1.3ms preprocess, 255.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# Model summary (fused): 112 layers, 43,607,379 parameters, 0 gradients, 164.8 GFLOPs
# 0: 384x640 1 neck, 293.3ms
# Speed: 2.6ms preprocess, 293.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 248.0ms
# Speed: 1.2ms preprocess, 248.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 291.3ms
# Speed: 2.2ms preprocess, 291.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 280.3ms
# Speed: 1.5ms preprocess, 280.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 202.3ms
# Speed: 1.8ms preprocess, 202.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 247.8ms
# Speed: 1.3ms preprocess, 247.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 284.2ms
# Speed: 2.8ms preprocess, 284.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 251.3ms
# Speed: 1.9ms preprocess, 251.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 225.5ms
# Speed: 2.1ms preprocess, 225.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 211.0ms
# Speed: 1.4ms preprocess, 211.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 273.2ms
# Speed: 1.8ms preprocess, 273.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 255.3ms
# Speed: 1.3ms preprocess, 255.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 234.1ms
# Speed: 1.8ms preprocess, 234.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 243.7ms
# Speed: 1.4ms preprocess, 243.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 250.2ms
# Speed: 1.7ms preprocess, 250.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 196.3ms
# Speed: 1.4ms preprocess, 196.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 247.1ms
# Speed: 1.9ms preprocess, 247.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 223.4ms
# Speed: 1.4ms preprocess, 223.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 279.2ms
# Speed: 1.8ms preprocess, 279.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 244.7ms
# Speed: 1.4ms preprocess, 244.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 247.3ms
# Speed: 1.5ms preprocess, 247.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 214.0ms
# Speed: 1.6ms preprocess, 214.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 215.9ms
# Speed: 2.0ms preprocess, 215.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 198.9ms
# Speed: 1.5ms preprocess, 198.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 202.6ms
# Speed: 2.0ms preprocess, 202.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 229.4ms
# Speed: 1.6ms preprocess, 229.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 272.1ms
# Speed: 1.9ms preprocess, 272.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 235.1ms
# Speed: 1.5ms preprocess, 235.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 206.1ms
# Speed: 1.9ms preprocess, 206.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 222.9ms
# Speed: 1.9ms preprocess, 222.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 266.0ms
# Speed: 1.4ms preprocess, 266.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 251.1ms
# Speed: 2.4ms preprocess, 251.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 258.8ms
# Speed: 1.5ms preprocess, 258.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 272.7ms
# Speed: 2.1ms preprocess, 272.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 289.1ms
# Speed: 1.5ms preprocess, 289.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 295.4ms
# Speed: 1.7ms preprocess, 295.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 267.3ms
# Speed: 1.3ms preprocess, 267.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 287.3ms
# Speed: 2.2ms preprocess, 287.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 263.2ms
# Speed: 1.3ms preprocess, 263.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 303.3ms
# Speed: 2.5ms preprocess, 303.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 295.7ms
# Speed: 1.3ms preprocess, 295.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 287.6ms
# Speed: 2.0ms preprocess, 287.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 302.1ms
# Speed: 1.2ms preprocess, 302.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# [Classify Start] ID 1
#
# [Classify Done] ID 1
# 0: 384x640 1 neck, 220.9ms
# Speed: 2.2ms preprocess, 220.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 279.7ms
# Speed: 1.5ms preprocess, 279.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 297.6ms
# Speed: 2.0ms preprocess, 297.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 214.3ms
# Speed: 1.5ms preprocess, 214.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 220.8ms
# Speed: 1.9ms preprocess, 220.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 224.7ms
# Speed: 1.2ms preprocess, 224.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 298.9ms
# Speed: 1.5ms preprocess, 298.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 258.0ms
# Speed: 1.2ms preprocess, 258.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 279.2ms
# Speed: 2.0ms preprocess, 279.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 274.3ms
# Speed: 2.1ms preprocess, 274.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 258.8ms
# Speed: 2.6ms preprocess, 258.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 273.3ms
# Speed: 1.3ms preprocess, 273.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 263.8ms
# Speed: 2.6ms preprocess, 263.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 260.0ms
# Speed: 1.4ms preprocess, 260.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 286.7ms
# Speed: 1.5ms preprocess, 286.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 238.8ms
# Speed: 1.4ms preprocess, 238.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 284.8ms
# Speed: 2.0ms preprocess, 284.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 253.3ms
# Speed: 1.3ms preprocess, 253.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 320.6ms
# Speed: 2.0ms preprocess, 320.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 264.0ms
# Speed: 1.4ms preprocess, 264.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 253.1ms
# Speed: 2.1ms preprocess, 253.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 219.0ms
# Speed: 1.3ms preprocess, 219.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 222.7ms
# Speed: 2.2ms preprocess, 222.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 202.1ms
# Speed: 1.4ms preprocess, 202.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 209.3ms
# Speed: 1.8ms preprocess, 209.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 208.0ms
# Speed: 1.8ms preprocess, 208.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 204.0ms
# Speed: 1.3ms preprocess, 204.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 212.9ms
# Speed: 1.8ms preprocess, 212.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 222.4ms
# Speed: 2.2ms preprocess, 222.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 283.3ms
# Speed: 1.5ms preprocess, 283.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 269.1ms
# Speed: 1.4ms preprocess, 269.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 208.1ms
# Speed: 1.9ms preprocess, 208.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 227.7ms
# Speed: 1.3ms preprocess, 227.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 242.7ms
# Speed: 1.6ms preprocess, 242.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 252.4ms
# Speed: 1.3ms preprocess, 252.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 262.9ms
# Speed: 1.7ms preprocess, 262.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 258.3ms
# Speed: 2.1ms preprocess, 258.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 257.3ms
# Speed: 1.8ms preprocess, 257.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 255.8ms
# Speed: 1.4ms preprocess, 255.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 260.3ms
# Speed: 2.0ms preprocess, 260.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 230.5ms
# Speed: 1.4ms preprocess, 230.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 230.8ms
# Speed: 2.0ms preprocess, 230.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 225.9ms
# Speed: 1.3ms preprocess, 225.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 239.6ms
# Speed: 1.6ms preprocess, 239.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 220.0ms
# Speed: 1.8ms preprocess, 220.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 262.3ms
# Speed: 1.3ms preprocess, 262.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 209.6ms
# Speed: 1.4ms preprocess, 209.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 243.9ms
# Speed: 1.8ms preprocess, 243.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 234.8ms
# Speed: 1.3ms preprocess, 234.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 231.7ms
# Speed: 1.3ms preprocess, 231.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 227.7ms
# Speed: 1.4ms preprocess, 227.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 270.4ms
# Speed: 2.1ms preprocess, 270.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 259.7ms
# Speed: 1.6ms preprocess, 259.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 285.2ms
# Speed: 1.3ms preprocess, 285.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 230.2ms
# Speed: 1.8ms preprocess, 230.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 232.8ms
# Speed: 1.3ms preprocess, 232.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 212.1ms
# Speed: 1.3ms preprocess, 212.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 198.5ms
# Speed: 2.0ms preprocess, 198.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 218.0ms
# Speed: 1.4ms preprocess, 218.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 303.8ms
# Speed: 2.1ms preprocess, 303.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 251.9ms
# Speed: 1.4ms preprocess, 251.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 284.9ms
# Speed: 2.3ms preprocess, 284.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 264.3ms
# Speed: 1.3ms preprocess, 264.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 263.1ms
# Speed: 2.0ms preprocess, 263.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 239.9ms
# Speed: 1.4ms preprocess, 239.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 235.8ms
# Speed: 2.1ms preprocess, 235.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 207.9ms
# Speed: 1.3ms preprocess, 207.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 241.6ms
# Speed: 2.0ms preprocess, 241.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 286.3ms
# Speed: 1.7ms preprocess, 286.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 279.9ms
# Speed: 1.3ms preprocess, 279.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 219.3ms
# Speed: 2.1ms preprocess, 219.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 256.6ms
# Speed: 1.8ms preprocess, 256.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 210.1ms
# Speed: 1.9ms preprocess, 210.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 227.8ms
# Speed: 1.3ms preprocess, 227.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 304.3ms
# Speed: 1.5ms preprocess, 304.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 289.1ms
# Speed: 2.1ms preprocess, 289.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 307.5ms
# Speed: 1.8ms preprocess, 307.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 313.0ms
# Speed: 1.8ms preprocess, 313.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 261.0ms
# Speed: 1.4ms preprocess, 261.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 292.9ms
# Speed: 1.4ms preprocess, 292.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 296.6ms
# Speed: 2.0ms preprocess, 296.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 299.1ms
# Speed: 1.8ms preprocess, 299.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 253.5ms
# Speed: 1.7ms preprocess, 253.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 231.8ms
# Speed: 2.1ms preprocess, 231.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 307.3ms
# Speed: 1.4ms preprocess, 307.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 286.9ms
# Speed: 2.2ms preprocess, 286.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 246.9ms
# Speed: 1.7ms preprocess, 246.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 288.0ms
# Speed: 1.7ms preprocess, 288.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 283.6ms
# Speed: 1.8ms preprocess, 283.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 275.0ms
# Speed: 1.3ms preprocess, 275.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 253.0ms
# Speed: 1.6ms preprocess, 253.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 232.2ms
# Speed: 2.0ms preprocess, 232.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 215.7ms
# Speed: 2.3ms preprocess, 215.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 219.6ms
# Speed: 1.3ms preprocess, 219.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 227.2ms
# Speed: 1.7ms preprocess, 227.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 254.8ms
# Speed: 2.3ms preprocess, 254.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 222.0ms
# Speed: 1.4ms preprocess, 222.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 267.7ms
# Speed: 2.5ms preprocess, 267.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 246.4ms
# Speed: 1.2ms preprocess, 246.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 240.8ms
# Speed: 2.1ms preprocess, 240.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 215.0ms
# Speed: 3.1ms preprocess, 215.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 219.2ms
# Speed: 1.6ms preprocess, 219.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 229.4ms
# Speed: 2.6ms preprocess, 229.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 241.1ms
# Speed: 1.3ms preprocess, 241.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# [Classify Start] ID 1
# [Classify Done] ID 1
# 0: 384x640 1 neck, 274.4ms
# Speed: 8.5ms preprocess, 274.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 272.8ms
# Speed: 7.4ms preprocess, 272.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 279.5ms
# Speed: 1.3ms preprocess, 279.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 311.8ms
# Speed: 1.9ms preprocess, 311.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 228.9ms
# Speed: 2.1ms preprocess, 228.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 221.7ms
# Speed: 1.3ms preprocess, 221.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 264.0ms
# Speed: 2.0ms preprocess, 264.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 249.2ms
# Speed: 1.3ms preprocess, 249.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 215.7ms
# Speed: 2.1ms preprocess, 215.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 236.6ms
# Speed: 1.4ms preprocess, 236.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 249.5ms
# Speed: 1.5ms preprocess, 249.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 236.7ms
# Speed: 2.1ms preprocess, 236.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 275.6ms
# Speed: 2.5ms preprocess, 275.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 308.8ms
# Speed: 1.3ms preprocess, 308.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 212.4ms
# Speed: 1.2ms preprocess, 212.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 246.0ms
# Speed: 2.0ms preprocess, 246.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 182.6ms
# Speed: 1.2ms preprocess, 182.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 229.6ms
# Speed: 1.7ms preprocess, 229.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 242.5ms
# Speed: 1.3ms preprocess, 242.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 282.5ms
# Speed: 1.7ms preprocess, 282.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 231.2ms
# Speed: 1.2ms preprocess, 231.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 253.7ms
# Speed: 2.0ms preprocess, 253.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 260.6ms
# Speed: 1.3ms preprocess, 260.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 277.1ms
# Speed: 1.4ms preprocess, 277.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 252.6ms
# Speed: 1.2ms preprocess, 252.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 271.7ms
# Speed: 2.6ms preprocess, 271.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 268.4ms
# Speed: 1.6ms preprocess, 268.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 295.3ms
# Speed: 2.0ms preprocess, 295.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 226.1ms
# Speed: 1.3ms preprocess, 226.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 234.0ms
# Speed: 2.3ms preprocess, 234.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 210.9ms
# Speed: 1.2ms preprocess, 210.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 254.5ms
# Speed: 2.2ms preprocess, 254.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 226.6ms
# Speed: 1.2ms preprocess, 226.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 299.9ms
# Speed: 1.9ms preprocess, 299.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 217.4ms
# Speed: 1.2ms preprocess, 217.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 243.0ms
# Speed: 2.2ms preprocess, 243.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 207.9ms
# Speed: 1.3ms preprocess, 207.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 240.5ms
# Speed: 2.3ms preprocess, 240.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 267.4ms
# Speed: 1.3ms preprocess, 267.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 298.4ms
# Speed: 1.9ms preprocess, 298.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 235.7ms
# Speed: 2.1ms preprocess, 235.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 241.8ms
# Speed: 2.0ms preprocess, 241.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 219.7ms
# Speed: 2.1ms preprocess, 219.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 292.9ms
# Speed: 1.8ms preprocess, 292.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 208.8ms
# Speed: 1.2ms preprocess, 208.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 261.8ms
# Speed: 1.9ms preprocess, 261.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 246.2ms
# Speed: 1.3ms preprocess, 246.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 242.6ms
# Speed: 3.4ms preprocess, 242.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 207.3ms
# Speed: 1.2ms preprocess, 207.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 280.9ms
# Speed: 2.5ms preprocess, 280.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 282.4ms
# Speed: 1.2ms preprocess, 282.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 250.3ms
# Speed: 2.0ms preprocess, 250.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 260.7ms
# Speed: 1.5ms preprocess, 260.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 306.5ms
# Speed: 2.3ms preprocess, 306.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 304.6ms
# Speed: 1.2ms preprocess, 304.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 241.5ms
# Speed: 1.8ms preprocess, 241.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 315.3ms
# Speed: 1.2ms preprocess, 315.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 290.9ms
# Speed: 1.8ms preprocess, 290.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 292.0ms
# Speed: 1.8ms preprocess, 292.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 301.1ms
# Speed: 1.3ms preprocess, 301.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 209.7ms
# Speed: 2.1ms preprocess, 209.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 268.3ms
# Speed: 1.4ms preprocess, 268.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 261.1ms
# Speed: 2.0ms preprocess, 261.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 274.7ms
# Speed: 1.2ms preprocess, 274.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 228.0ms
# Speed: 1.3ms preprocess, 228.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 273.6ms
# Speed: 2.0ms preprocess, 273.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 287.7ms
# Speed: 1.3ms preprocess, 287.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 292.2ms
# Speed: 2.2ms preprocess, 292.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 221.6ms
# Speed: 2.0ms preprocess, 221.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 297.1ms
# Speed: 1.4ms preprocess, 297.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 253.9ms
# Speed: 1.3ms preprocess, 253.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 304.6ms
# Speed: 2.7ms preprocess, 304.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 261.0ms
# Speed: 1.3ms preprocess, 261.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 307.1ms
# Speed: 1.6ms preprocess, 307.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 256.1ms
# Speed: 1.2ms preprocess, 256.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 287.4ms
# Speed: 2.2ms preprocess, 287.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 254.5ms
# Speed: 1.2ms preprocess, 254.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 283.4ms
# Speed: 2.7ms preprocess, 283.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 250.6ms
# Speed: 1.3ms preprocess, 250.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 310.6ms
# Speed: 1.8ms preprocess, 310.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 236.1ms
# Speed: 1.3ms preprocess, 236.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 249.6ms
# Speed: 1.7ms preprocess, 249.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 200.0ms
# Speed: 1.2ms preprocess, 200.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 255.0ms
# Speed: 2.2ms preprocess, 255.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 213.1ms
# Speed: 1.2ms preprocess, 213.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 284.1ms
# Speed: 1.8ms preprocess, 284.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 277.5ms
# Speed: 1.9ms preprocess, 277.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 275.2ms
# Speed: 1.7ms preprocess, 275.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 305.5ms
# Speed: 1.3ms preprocess, 305.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 239.5ms
# Speed: 1.6ms preprocess, 239.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 269.2ms
# Speed: 1.9ms preprocess, 269.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 271.9ms
# Speed: 2.4ms preprocess, 271.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 245.6ms
# Speed: 1.2ms preprocess, 245.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 276.7ms
# Speed: 1.7ms preprocess, 276.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 259.2ms
# Speed: 1.2ms preprocess, 259.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 263.3ms
# Speed: 1.9ms preprocess, 263.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 246.9ms
# Speed: 1.2ms preprocess, 246.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 245.8ms
# Speed: 2.0ms preprocess, 245.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 183.5ms
# Speed: 1.2ms preprocess, 183.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 257.3ms
# Speed: 1.6ms preprocess, 257.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 186.0ms
# Speed: 1.2ms preprocess, 186.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 202.5ms
# Speed: 1.4ms preprocess, 202.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 230.6ms
# Speed: 1.3ms preprocess, 230.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 236.1ms
# Speed: 1.6ms preprocess, 236.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 226.6ms
# Speed: 1.2ms preprocess, 226.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 273.0ms
# Speed: 1.7ms preprocess, 273.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 233.5ms
# Speed: 1.3ms preprocess, 233.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 207.5ms
# Speed: 1.8ms preprocess, 207.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 260.2ms
# Speed: 1.2ms preprocess, 260.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 237.2ms
# Speed: 1.7ms preprocess, 237.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 191.5ms
# Speed: 1.8ms preprocess, 191.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 279.1ms
# Speed: 1.3ms preprocess, 279.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 210.5ms
# Speed: 1.9ms preprocess, 210.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 222.7ms
# Speed: 1.6ms preprocess, 222.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 272.3ms
# Speed: 2.3ms preprocess, 272.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 258.9ms
# Speed: 1.6ms preprocess, 258.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 247.5ms
# Speed: 2.2ms preprocess, 247.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 254.6ms
# Speed: 1.4ms preprocess, 254.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 227.4ms
# Speed: 2.5ms preprocess, 227.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 217.4ms
# Speed: 1.8ms preprocess, 217.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 274.1ms
# Speed: 1.7ms preprocess, 274.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 258.1ms
# Speed: 1.6ms preprocess, 258.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 243.7ms
# Speed: 1.4ms preprocess, 243.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 243.8ms
# Speed: 1.6ms preprocess, 243.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 222.7ms
# Speed: 1.2ms preprocess, 222.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 254.6ms
# Speed: 2.7ms preprocess, 254.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 220.3ms
# Speed: 1.3ms preprocess, 220.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 242.7ms
# Speed: 1.9ms preprocess, 242.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 208.5ms
# Speed: 2.0ms preprocess, 208.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 241.9ms
# Speed: 2.3ms preprocess, 241.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 253.9ms
# Speed: 1.2ms preprocess, 253.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 298.5ms
# Speed: 1.8ms preprocess, 298.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 269.7ms
# Speed: 1.3ms preprocess, 269.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 277.6ms
# Speed: 2.3ms preprocess, 277.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 269.9ms
# Speed: 1.3ms preprocess, 269.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 300.7ms
# Speed: 2.0ms preprocess, 300.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 284.1ms
# Speed: 1.3ms preprocess, 284.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 290.6ms
# Speed: 1.8ms preprocess, 290.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 281.2ms
# Speed: 1.3ms preprocess, 281.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 302.4ms
# Speed: 1.7ms preprocess, 302.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 273.1ms
# Speed: 1.3ms preprocess, 273.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 neck, 283.9ms
# Speed: 1.8ms preprocess, 283.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 279.7ms
# Speed: 2.3ms preprocess, 279.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 292.1ms
# Speed: 1.9ms preprocess, 292.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 265.5ms
# Speed: 1.7ms preprocess, 265.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 279.1ms
# Speed: 1.3ms preprocess, 279.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 200.3ms
# Speed: 1.8ms preprocess, 200.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 216.4ms
# Speed: 1.2ms preprocess, 216.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 277.0ms
# Speed: 1.9ms preprocess, 277.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 270.5ms
# Speed: 1.4ms preprocess, 270.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 203.9ms
# Speed: 1.3ms preprocess, 203.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 252.1ms
# Speed: 2.2ms preprocess, 252.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 200.0ms
# Speed: 1.3ms preprocess, 200.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 211.6ms
# Speed: 2.1ms preprocess, 211.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 256.9ms
# Speed: 1.3ms preprocess, 256.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 265.9ms
# Speed: 2.3ms preprocess, 265.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 277.8ms
# Speed: 1.8ms preprocess, 277.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 279.4ms
# Speed: 1.6ms preprocess, 279.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 207.6ms
# Speed: 2.5ms preprocess, 207.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 199.6ms
# Speed: 1.3ms preprocess, 199.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 216.3ms
# Speed: 2.0ms preprocess, 216.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 203.7ms
# Speed: 1.2ms preprocess, 203.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 210.3ms
# Speed: 1.2ms preprocess, 210.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# [Classify Start] ID 1
# 0: 384x640 1 neck, 241.9ms
# Speed: 1.9ms preprocess, 241.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [Classify Done] ID 1
# 0: 384x640 1 neck, 266.9ms
# Speed: 2.3ms preprocess, 266.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 266.1ms
# Speed: 6.4ms preprocess, 266.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 216.4ms
# Speed: 1.9ms preprocess, 216.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 262.7ms
# Speed: 1.8ms preprocess, 262.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 202.4ms
# Speed: 1.2ms preprocess, 202.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 214.1ms
# Speed: 2.1ms preprocess, 214.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 251.1ms
# Speed: 1.3ms preprocess, 251.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 273.3ms
# Speed: 2.1ms preprocess, 273.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 242.9ms
# Speed: 1.1ms preprocess, 242.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 265.5ms
# Speed: 2.0ms preprocess, 265.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 211.8ms
# Speed: 1.3ms preprocess, 211.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 224.4ms
#
# Speed: 2.3ms preprocess, 224.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 221.9ms
# Speed: 1.3ms preprocess, 221.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 neck, 244.9ms
# Speed: 1.6ms preprocess, 244.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 neck, 244.8ms
# Speed: 2.2ms preprocess, 244.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 257.3ms
# Speed: 1.9ms preprocess, 257.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 245.3ms
# Speed: 2.4ms preprocess, 245.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 228.7ms
# Speed: 1.3ms preprocess, 228.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 224.5ms
# Speed: 1.4ms preprocess, 224.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 302.8ms
# Speed: 1.5ms preprocess, 302.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 258.6ms
# Speed: 1.2ms preprocess, 258.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 262.8ms
# Speed: 2.2ms preprocess, 262.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 232.9ms
# Speed: 1.2ms preprocess, 232.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# [Classify Start] ID 1
# 0: 384x640 1 neck, 238.0ms
# Speed: 2.4ms preprocess, 238.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [Classify Done] ID 1
# 0: 384x640 1 neck, 224.6ms
# Speed: 2.3ms preprocess, 224.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 225.1ms
# Speed: 6.9ms preprocess, 225.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 208.7ms
# Speed: 2.5ms preprocess, 208.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 192.3ms
# Speed: 1.3ms preprocess, 192.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 290.5ms
# Speed: 2.0ms preprocess, 290.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 301.8ms
# Speed: 1.3ms preprocess, 301.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 229.6ms
# Speed: 2.1ms preprocess, 229.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 238.4ms
# Speed: 2.1ms preprocess, 238.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 249.7ms
# Speed: 1.8ms preprocess, 249.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 267.4ms
# Speed: 1.4ms preprocess, 267.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 253.8ms
# Speed: 1.7ms preprocess, 253.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 254.3ms
# Speed: 1.6ms preprocess, 254.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 218.4ms
# Speed: 2.0ms preprocess, 218.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 226.5ms
# Speed: 1.3ms preprocess, 226.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 202.8ms
# Speed: 1.4ms preprocess, 202.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 194.7ms
# Speed: 1.5ms preprocess, 194.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 238.2ms
# Speed: 1.8ms preprocess, 238.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 235.0ms
# Speed: 1.3ms preprocess, 235.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 265.6ms
# Speed: 2.7ms preprocess, 265.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 270.1ms
# Speed: 1.4ms preprocess, 270.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 262.8ms
# Speed: 1.4ms preprocess, 262.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 256.7ms
# Speed: 1.6ms preprocess, 256.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 220.9ms
# Speed: 1.6ms preprocess, 220.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 237.8ms
# Speed: 1.6ms preprocess, 237.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# [Classify Start] ID 1
# [Classify Done] ID 1
# 0: 384x640 1 chicken, 270.6ms
# Speed: 7.2ms preprocess, 270.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 310.8ms
# Speed: 2.0ms preprocess, 310.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 260.8ms
# Speed: 1.9ms preprocess, 260.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 270.6ms
# ...
# 0: 384x640 1 chicken, 214.9ms
# Speed: 1.3ms preprocess, 214.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 232.1ms
# Speed: 1.7ms preprocess, 232.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 neck, 252.0ms
# Speed: 2.1ms preprocess, 252.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 291.1ms
# Speed: 2.0ms preprocess, 291.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 284.7ms
# Speed: 2.0ms preprocess, 284.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 258.0ms
# Speed: 2.0ms preprocess, 258.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 252.5ms
# Speed: 1.2ms preprocess, 252.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 chicken, 200.4ms
# Speed: 1.5ms preprocess, 200.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 1 neck, 242.0ms
# Speed: 1.4ms preprocess, 242.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 241.2ms
# Speed: 1.2ms preprocess, 241.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 303.9ms
# Speed: 1.7ms preprocess, 303.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 254.4ms
# Speed: 1.3ms preprocess, 254.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 245.6ms
# Speed: 1.7ms preprocess, 245.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 257.6ms
# Speed: 1.2ms preprocess, 257.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 262.6ms
# Speed: 1.4ms preprocess, 262.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 chicken, 261.0ms
# Speed: 2.1ms preprocess, 261.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 292.4ms
# Speed: 1.9ms preprocess, 292.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 (no detections), 192.7ms
# Speed: 1.5ms preprocess, 192.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 195.5ms
# Speed: 1.3ms preprocess, 195.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 264.3ms
# Speed: 1.9ms preprocess, 264.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 276.7ms
# Speed: 1.3ms preprocess, 276.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 240.1ms
# Speed: 1.9ms preprocess, 240.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 267.0ms
# Speed: 1.3ms preprocess, 267.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 198.8ms
# Speed: 1.8ms preprocess, 198.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 203.4ms
# Speed: 1.4ms preprocess, 203.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 270.1ms
# Speed: 1.9ms preprocess, 270.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 280.3ms
# Speed: 1.3ms preprocess, 280.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 271.4ms
# Speed: 2.1ms preprocess, 271.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 268.5ms
# Speed: 1.3ms preprocess, 268.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 220.6ms
# Speed: 1.9ms preprocess, 220.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 226.8ms
# Speed: 1.3ms preprocess, 226.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 190.5ms
# Speed: 2.1ms preprocess, 190.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 186.6ms
# Speed: 1.3ms preprocess, 186.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 219.4ms
# Speed: 1.8ms preprocess, 219.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 211.7ms
# Speed: 1.2ms preprocess, 211.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
#
# 0: 384x640 (no detections), 225.1ms
# Speed: 1.7ms preprocess, 225.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 chicken, 227.3ms
# Speed: 2.4ms preprocess, 227.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-0db94c6fca5e> in <cell line: 0>()
#       1 #run_detection_and_tracking("/content/drive/MyDrive/FYP models/test_models/Test_images/chicken-4392787.jpg")
#       2 #run_detection_and_tracking("/content/drive/MyDrive/FYP models/test_models/Test_images")
# ----> 3 run_detection_and_tracking("/content/drive/MyDrive/FYP models/test_models/test_videos/165148-832090850.mp4")
#       4 #/content/drive/MyDrive/FYP models/test_models/test_videos/MXClip_N_C_D.mp4
#       5 #/content/drive/MyDrive/FYP models/test_models/test_videos/130614-747879918_large.mp4
#
# <ipython-input-62-551dd86ad890> in run_detection_and_tracking(input_path)
#      13             model.predictor.tracker = None
#      14
# ---> 15         process_video(input_path, output_dir)
#      16
#      17     elif input_path.is_dir():
#
# <ipython-input-61-2e4578609081> in process_video(video_path, output_dir)
#      17             break
#      18
# ---> 19         results = model.track(frame, persist=True, conf=0.5, iou=0.5, tracker="botsort.yaml")[0]
#      20         detections = []
#      21
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in track(self, source, stream, persist, **kwargs)
#     594         kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     595         kwargs["mode"] = "track"
# --> 596         return self.predict(source=source, stream=stream, **kwargs)
#     597
#     598     def val(
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     550         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     551             self.predictor.set_prompts(prompts)
# --> 552         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     553
#     554     def track(
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     216             return self.stream_inference(source, model, *args, **kwargs)
#     217         else:
# --> 218             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#     219
#     220     def predict_cli(self, source=None, model=None):
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in generator_context(*args, **kwargs)
#      34             # Issuing `None` to a generator fires it up
#      35             with ctx_factory():
# ---> 36                 response = gen.send(None)
#      37
#      38             while True:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     328                 # Inference
#     329                 with profilers[1]:
# --> 330                     preds = self.inference(im, *args, **kwargs)
#     331                     if self.args.embed:
#     332                         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in inference(self, im, *args, **kwargs)
#     171             else False
#     172         )
# --> 173         return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#     174
#     175     def pre_transform(self, im):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/autobackend.py in forward(self, im, augment, visualize, embed, **kwargs)
#     590         # PyTorch
#     591         if self.pt or self.nn_module:
# --> 592             y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     593
#     594         # TorchScript
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in forward(self, x, *args, **kwargs)
#     113         if isinstance(x, dict):  # for cases of training and validating while training.
#     114             return self.loss(x, *args, **kwargs)
# --> 115         return self.predict(x, *args, **kwargs)
#     116
#     117     def predict(self, x, profile=False, visualize=False, augment=False, embed=None):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in predict(self, x, profile, visualize, augment, embed)
#     131         if augment:
#     132             return self._predict_augment(x)
# --> 133         return self._predict_once(x, profile, visualize, embed)
#     134
#     135     def _predict_once(self, x, profile=False, visualize=False, embed=None):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in _predict_once(self, x, profile, visualize, embed)
#     152             if profile:
#     153                 self._profile_one_layer(m, x, dt)
# --> 154             x = m(x)  # run
#     155             y.append(x if m.i in self.save else None)  # save output
#     156             if visualize:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py in forward(self, x)
#     299         """Forward pass through C2f layer."""
#     300         y = list(self.cv1(x).chunk(2, 1))
# --> 301         y.extend(m(y[-1]) for m in self.m)
#     302         return self.cv2(torch.cat(y, 1))
#     303
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py in <genexpr>(.0)
#     299         """Forward pass through C2f layer."""
#     300         y = list(self.cv1(x).chunk(2, 1))
# --> 301         y.extend(m(y[-1]) for m in self.m)
#     302         return self.cv2(torch.cat(y, 1))
#     303
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py in forward(self, x)
#     474     def forward(self, x):
#     475         """Apply bottleneck with optional shortcut connection."""
# --> 476         return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#     477
#     478
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/conv.py in forward_fuse(self, x)
#      89             (torch.Tensor): Output tensor.
#      90         """
# ---> 91         return self.act(self.conv(x))
#      92
#      93
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# KeyboardInterrupt:
